# %% [markdown]
# # 個人課題１

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time
import json

# %%
path = ''
db_name = 'repository.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # テーブルが既に存在するかチェック
    cur.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='repository';")
    table_exists = cur.fetchone() is not None

    if table_exists:
        # 既存テーブルをクリア（データをすべて削除）
        cur.execute("DELETE FROM repository;")
        conn.commit()
        print("既存のテーブルをクリアしました")
    else:
        # テーブルを作成
        sql = 'CREATE TABLE repository (id INT, name TEXT , language TEXT, stars INT);'
        cur.execute(sql)
        conn.commit()
        print("テーブルを作成しました")

except sqlite3.Error as e:
    print(f"エラーが発生しました: {e}")

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# 既存のテーブルをクリアしました

# %%
path = ''
db_name = 'repository.db'

# スクレイピング（URL パラメータでページング）
base_url = "https://github.com/orgs/google/repositories"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

page = 1
total_repos_fetched = 0
total_repos_this_page = 0

print("=== Google Organization の全リポジトリを取得開始 ===\n")

while True:
    # URL にページパラメータを指定
    url = base_url if page == 1 else f"{base_url}?page={page}"
    
    print(f"ページ {page} を取得中... (URL: {url[:80]}...)")
    response = requests.get(url, headers=headers)
    print(f"ステータスコード: {response.status_code}")

    #　ステータスコードが200以外の場合に例外を発生させる
    response.raise_for_status()

    soup = BeautifulSoup(response.content, "html.parser")

    # JSON データから抽出（より安定的）
    script_tag = soup.find("script", attrs={"data-target": "react-app.embeddedData"})
    if not script_tag:
        print(f"ページ {page}: embeddedData スクリプトタグが見つかりません。スクレイピング終了")
        break

    # JSON データの抽出
    data = json.loads(script_tag.string)

    # repositories はここに入っている（GitHub の構造）
    repo_list = data["payload"]["orgReposPageRoute"]["repositories"]
    
    if not repo_list:
        print(f"ページ {page}: リポジトリが見つかりません。スクレイピング終了")
        break

    print(f"このページで取得したリポジトリ数: {len(repo_list)}")
    total_repos_this_page = len(repo_list)

    for repo_item in repo_list:
        repo_name = repo_item["name"]
        repo_language = repo_item["primaryLanguage"]["name"] if repo_item.get("primaryLanguage") else "Unknown"
        repo_stars = repo_item.get("starsCount", 0)

        # サーバーに負荷をかけないように0.1秒待機
        time.sleep(0.1)

        try:
            # DB接続オブジェクトの作成
            conn = sqlite3.connect(path + db_name)

            # SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトを取得
            cur = conn.cursor()

            # データ挿入SQL
            sql = "INSERT INTO repository (id, name, language, stars) VALUES (?, ?, ?, ?);"

            # SQL文の実行
            cur.execute(sql, (None, repo_name, repo_language, repo_stars))

            # 変更をDBに反映させる
            conn.commit()
            total_repos_fetched += 1

        except sqlite3.Error as e:
            print(f"  エラーが発生しました ({repo_name}): {e}")

        finally:
            # DBへの接続を閉じる
            conn.close()

    # 次ページの存在を確認
    # リポジトリ数が30未満の場合は最後のページと判定
    if total_repos_this_page < 30:
        print(f"\nページ {page}: リポジトリ数が30未満。スクレイピング終了")
        break

    page += 1
    print(f"合計 {total_repos_fetched} 個取得...\n")

print(f"\n=== スクレイピング完了 ===")
print(f"合計 {total_repos_fetched} 個のリポジトリをデータベースに保存しました")
# Out:
# === Google Organization の全リポジトリを取得開始 ===
#
# ページ 1 を取得中... (URL: https://github.com/orgs/google/repositories...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 30 個取得...
#
# ページ 2 を取得中... (URL: https://github.com/orgs/google/repositories?page=2...)
# 合計 30 個取得...
#
# ページ 2 を取得中... (URL: https://github.com/orgs/google/repositories?page=2...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 60 個取得...
#
# ページ 3 を取得中... (URL: https://github.com/orgs/google/repositories?page=3...)
# 合計 60 個取得...
#
# ページ 3 を取得中... (URL: https://github.com/orgs/google/repositories?page=3...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 90 個取得...
#
# ページ 4 を取得中... (URL: https://github.com/orgs/google/repositories?page=4...)
# 合計 90 個取得...
#
# ページ 4 を取得中... (URL: https://github.com/orgs/google/repositories?page=4...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 120 個取得...
#
# ページ 5 を取得中... (URL: https://github.com/orgs/google/repositories?page=5...)
# 合計 120 個取得...
#
# ページ 5 を取得中... (URL: https://github.com/orgs/google/repositories?page=5...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 150 個取得...
#
# ページ 6 を取得中... (URL: https://github.com/orgs/google/repositories?page=6...)
# 合計 150 個取得...
#
# ページ 6 を取得中... (URL: https://github.com/orgs/google/repositories?page=6...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 180 個取得...
#
# ページ 7 を取得中... (URL: https://github.com/orgs/google/repositories?page=7...)
# 合計 180 個取得...
#
# ページ 7 を取得中... (URL: https://github.com/orgs/google/repositories?page=7...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 210 個取得...
#
# ページ 8 を取得中... (URL: https://github.com/orgs/google/repositories?page=8...)
# 合計 210 個取得...
#
# ページ 8 を取得中... (URL: https://github.com/orgs/google/repositories?page=8...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 240 個取得...
#
# ページ 9 を取得中... (URL: https://github.com/orgs/google/repositories?page=9...)
# 合計 240 個取得...
#
# ページ 9 を取得中... (URL: https://github.com/orgs/google/repositories?page=9...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 270 個取得...
#
# ページ 10 を取得中... (URL: https://github.com/orgs/google/repositories?page=10...)
# 合計 270 個取得...
#
# ページ 10 を取得中... (URL: https://github.com/orgs/google/repositories?page=10...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 300 個取得...
#
# ページ 11 を取得中... (URL: https://github.com/orgs/google/repositories?page=11...)
# 合計 300 個取得...
#
# ページ 11 を取得中... (URL: https://github.com/orgs/google/repositories?page=11...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 330 個取得...
#
# ページ 12 を取得中... (URL: https://github.com/orgs/google/repositories?page=12...)
# 合計 330 個取得...
#
# ページ 12 を取得中... (URL: https://github.com/orgs/google/repositories?page=12...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 360 個取得...
#
# ページ 13 を取得中... (URL: https://github.com/orgs/google/repositories?page=13...)
# 合計 360 個取得...
#
# ページ 13 を取得中... (URL: https://github.com/orgs/google/repositories?page=13...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 390 個取得...
#
# ページ 14 を取得中... (URL: https://github.com/orgs/google/repositories?page=14...)
# 合計 390 個取得...
#
# ページ 14 を取得中... (URL: https://github.com/orgs/google/repositories?page=14...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 420 個取得...
#
# ページ 15 を取得中... (URL: https://github.com/orgs/google/repositories?page=15...)
# 合計 420 個取得...
#
# ページ 15 を取得中... (URL: https://github.com/orgs/google/repositories?page=15...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 450 個取得...
#
# ページ 16 を取得中... (URL: https://github.com/orgs/google/repositories?page=16...)
# 合計 450 個取得...
#
# ページ 16 を取得中... (URL: https://github.com/orgs/google/repositories?page=16...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 480 個取得...
#
# ページ 17 を取得中... (URL: https://github.com/orgs/google/repositories?page=17...)
# 合計 480 個取得...
#
# ページ 17 を取得中... (URL: https://github.com/orgs/google/repositories?page=17...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 510 個取得...
#
# ページ 18 を取得中... (URL: https://github.com/orgs/google/repositories?page=18...)
# 合計 510 個取得...
#
# ページ 18 を取得中... (URL: https://github.com/orgs/google/repositories?page=18...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 540 個取得...
#
# ページ 19 を取得中... (URL: https://github.com/orgs/google/repositories?page=19...)
# 合計 540 個取得...
#
# ページ 19 を取得中... (URL: https://github.com/orgs/google/repositories?page=19...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 570 個取得...
#
# ページ 20 を取得中... (URL: https://github.com/orgs/google/repositories?page=20...)
# 合計 570 個取得...
#
# ページ 20 を取得中... (URL: https://github.com/orgs/google/repositories?page=20...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 600 個取得...
#
# ページ 21 を取得中... (URL: https://github.com/orgs/google/repositories?page=21...)
# 合計 600 個取得...
#
# ページ 21 を取得中... (URL: https://github.com/orgs/google/repositories?page=21...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 630 個取得...
#
# ページ 22 を取得中... (URL: https://github.com/orgs/google/repositories?page=22...)
# 合計 630 個取得...
#
# ページ 22 を取得中... (URL: https://github.com/orgs/google/repositories?page=22...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 660 個取得...
#
# ページ 23 を取得中... (URL: https://github.com/orgs/google/repositories?page=23...)
# 合計 660 個取得...
#
# ページ 23 を取得中... (URL: https://github.com/orgs/google/repositories?page=23...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 690 個取得...
#
# ページ 24 を取得中... (URL: https://github.com/orgs/google/repositories?page=24...)
# 合計 690 個取得...
#
# ページ 24 を取得中... (URL: https://github.com/orgs/google/repositories?page=24...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 720 個取得...
#
# ページ 25 を取得中... (URL: https://github.com/orgs/google/repositories?page=25...)
# 合計 720 個取得...
#
# ページ 25 を取得中... (URL: https://github.com/orgs/google/repositories?page=25...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 750 個取得...
#
# ページ 26 を取得中... (URL: https://github.com/orgs/google/repositories?page=26...)
# 合計 750 個取得...
#
# ページ 26 を取得中... (URL: https://github.com/orgs/google/repositories?page=26...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 780 個取得...
#
# ページ 27 を取得中... (URL: https://github.com/orgs/google/repositories?page=27...)
# 合計 780 個取得...
#
# ページ 27 を取得中... (URL: https://github.com/orgs/google/repositories?page=27...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 810 個取得...
#
# ページ 28 を取得中... (URL: https://github.com/orgs/google/repositories?page=28...)
# 合計 810 個取得...
#
# ページ 28 を取得中... (URL: https://github.com/orgs/google/repositories?page=28...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 840 個取得...
#
# ページ 29 を取得中... (URL: https://github.com/orgs/google/repositories?page=29...)
# 合計 840 個取得...
#
# ページ 29 を取得中... (URL: https://github.com/orgs/google/repositories?page=29...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 870 個取得...
#
# ページ 30 を取得中... (URL: https://github.com/orgs/google/repositories?page=30...)
# 合計 870 個取得...
#
# ページ 30 を取得中... (URL: https://github.com/orgs/google/repositories?page=30...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 900 個取得...
#
# ページ 31 を取得中... (URL: https://github.com/orgs/google/repositories?page=31...)
# 合計 900 個取得...
#
# ページ 31 を取得中... (URL: https://github.com/orgs/google/repositories?page=31...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 930 個取得...
#
# ページ 32 を取得中... (URL: https://github.com/orgs/google/repositories?page=32...)
# 合計 930 個取得...
#
# ページ 32 を取得中... (URL: https://github.com/orgs/google/repositories?page=32...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 960 個取得...
#
# ページ 33 を取得中... (URL: https://github.com/orgs/google/repositories?page=33...)
# 合計 960 個取得...
#
# ページ 33 を取得中... (URL: https://github.com/orgs/google/repositories?page=33...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 990 個取得...
#
# ページ 34 を取得中... (URL: https://github.com/orgs/google/repositories?page=34...)
# 合計 990 個取得...
#
# ページ 34 を取得中... (URL: https://github.com/orgs/google/repositories?page=34...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1020 個取得...
#
# ページ 35 を取得中... (URL: https://github.com/orgs/google/repositories?page=35...)
# 合計 1020 個取得...
#
# ページ 35 を取得中... (URL: https://github.com/orgs/google/repositories?page=35...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1050 個取得...
#
# ページ 36 を取得中... (URL: https://github.com/orgs/google/repositories?page=36...)
# 合計 1050 個取得...
#
# ページ 36 を取得中... (URL: https://github.com/orgs/google/repositories?page=36...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1080 個取得...
#
# ページ 37 を取得中... (URL: https://github.com/orgs/google/repositories?page=37...)
# 合計 1080 個取得...
#
# ページ 37 を取得中... (URL: https://github.com/orgs/google/repositories?page=37...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1110 個取得...
#
# ページ 38 を取得中... (URL: https://github.com/orgs/google/repositories?page=38...)
# 合計 1110 個取得...
#
# ページ 38 を取得中... (URL: https://github.com/orgs/google/repositories?page=38...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1140 個取得...
#
# ページ 39 を取得中... (URL: https://github.com/orgs/google/repositories?page=39...)
# 合計 1140 個取得...
#
# ページ 39 を取得中... (URL: https://github.com/orgs/google/repositories?page=39...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1170 個取得...
#
# ページ 40 を取得中... (URL: https://github.com/orgs/google/repositories?page=40...)
# 合計 1170 個取得...
#
# ページ 40 を取得中... (URL: https://github.com/orgs/google/repositories?page=40...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1200 個取得...
#
# ページ 41 を取得中... (URL: https://github.com/orgs/google/repositories?page=41...)
# 合計 1200 個取得...
#
# ページ 41 を取得中... (URL: https://github.com/orgs/google/repositories?page=41...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1230 個取得...
#
# ページ 42 を取得中... (URL: https://github.com/orgs/google/repositories?page=42...)
# 合計 1230 個取得...
#
# ページ 42 を取得中... (URL: https://github.com/orgs/google/repositories?page=42...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1260 個取得...
#
# ページ 43 を取得中... (URL: https://github.com/orgs/google/repositories?page=43...)
# 合計 1260 個取得...
#
# ページ 43 を取得中... (URL: https://github.com/orgs/google/repositories?page=43...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1290 個取得...
#
# ページ 44 を取得中... (URL: https://github.com/orgs/google/repositories?page=44...)
# 合計 1290 個取得...
#
# ページ 44 を取得中... (URL: https://github.com/orgs/google/repositories?page=44...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1320 個取得...
#
# ページ 45 を取得中... (URL: https://github.com/orgs/google/repositories?page=45...)
# 合計 1320 個取得...
#
# ページ 45 を取得中... (URL: https://github.com/orgs/google/repositories?page=45...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1350 個取得...
#
# ページ 46 を取得中... (URL: https://github.com/orgs/google/repositories?page=46...)
# 合計 1350 個取得...
#
# ページ 46 を取得中... (URL: https://github.com/orgs/google/repositories?page=46...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1380 個取得...
#
# ページ 47 を取得中... (URL: https://github.com/orgs/google/repositories?page=47...)
# 合計 1380 個取得...
#
# ページ 47 を取得中... (URL: https://github.com/orgs/google/repositories?page=47...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1410 個取得...
#
# ページ 48 を取得中... (URL: https://github.com/orgs/google/repositories?page=48...)
# 合計 1410 個取得...
#
# ページ 48 を取得中... (URL: https://github.com/orgs/google/repositories?page=48...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1440 個取得...
#
# ページ 49 を取得中... (URL: https://github.com/orgs/google/repositories?page=49...)
# 合計 1440 個取得...
#
# ページ 49 を取得中... (URL: https://github.com/orgs/google/repositories?page=49...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1470 個取得...
#
# ページ 50 を取得中... (URL: https://github.com/orgs/google/repositories?page=50...)
# 合計 1470 個取得...
#
# ページ 50 を取得中... (URL: https://github.com/orgs/google/repositories?page=50...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1500 個取得...
#
# ページ 51 を取得中... (URL: https://github.com/orgs/google/repositories?page=51...)
# 合計 1500 個取得...
#
# ページ 51 を取得中... (URL: https://github.com/orgs/google/repositories?page=51...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1530 個取得...
#
# ページ 52 を取得中... (URL: https://github.com/orgs/google/repositories?page=52...)
# 合計 1530 個取得...
#
# ページ 52 を取得中... (URL: https://github.com/orgs/google/repositories?page=52...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1560 個取得...
#
# ページ 53 を取得中... (URL: https://github.com/orgs/google/repositories?page=53...)
# 合計 1560 個取得...
#
# ページ 53 を取得中... (URL: https://github.com/orgs/google/repositories?page=53...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1590 個取得...
#
# ページ 54 を取得中... (URL: https://github.com/orgs/google/repositories?page=54...)
# 合計 1590 個取得...
#
# ページ 54 を取得中... (URL: https://github.com/orgs/google/repositories?page=54...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1620 個取得...
#
# ページ 55 を取得中... (URL: https://github.com/orgs/google/repositories?page=55...)
# 合計 1620 個取得...
#
# ページ 55 を取得中... (URL: https://github.com/orgs/google/repositories?page=55...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1650 個取得...
#
# ページ 56 を取得中... (URL: https://github.com/orgs/google/repositories?page=56...)
# 合計 1650 個取得...
#
# ページ 56 を取得中... (URL: https://github.com/orgs/google/repositories?page=56...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1680 個取得...
#
# ページ 57 を取得中... (URL: https://github.com/orgs/google/repositories?page=57...)
# 合計 1680 個取得...
#
# ページ 57 を取得中... (URL: https://github.com/orgs/google/repositories?page=57...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1710 個取得...
#
# ページ 58 を取得中... (URL: https://github.com/orgs/google/repositories?page=58...)
# 合計 1710 個取得...
#
# ページ 58 を取得中... (URL: https://github.com/orgs/google/repositories?page=58...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1740 個取得...
#
# ページ 59 を取得中... (URL: https://github.com/orgs/google/repositories?page=59...)
# 合計 1740 個取得...
#
# ページ 59 を取得中... (URL: https://github.com/orgs/google/repositories?page=59...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1770 個取得...
#
# ページ 60 を取得中... (URL: https://github.com/orgs/google/repositories?page=60...)
# 合計 1770 個取得...
#
# ページ 60 を取得中... (URL: https://github.com/orgs/google/repositories?page=60...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1800 個取得...
#
# ページ 61 を取得中... (URL: https://github.com/orgs/google/repositories?page=61...)
# 合計 1800 個取得...
#
# ページ 61 を取得中... (URL: https://github.com/orgs/google/repositories?page=61...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1830 個取得...
#
# ページ 62 を取得中... (URL: https://github.com/orgs/google/repositories?page=62...)
# 合計 1830 個取得...
#
# ページ 62 を取得中... (URL: https://github.com/orgs/google/repositories?page=62...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1860 個取得...
#
# ページ 63 を取得中... (URL: https://github.com/orgs/google/repositories?page=63...)
# 合計 1860 個取得...
#
# ページ 63 を取得中... (URL: https://github.com/orgs/google/repositories?page=63...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1890 個取得...
#
# ページ 64 を取得中... (URL: https://github.com/orgs/google/repositories?page=64...)
# 合計 1890 個取得...
#
# ページ 64 を取得中... (URL: https://github.com/orgs/google/repositories?page=64...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1920 個取得...
#
# ページ 65 を取得中... (URL: https://github.com/orgs/google/repositories?page=65...)
# 合計 1920 個取得...
#
# ページ 65 を取得中... (URL: https://github.com/orgs/google/repositories?page=65...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1950 個取得...
#
# ページ 66 を取得中... (URL: https://github.com/orgs/google/repositories?page=66...)
# 合計 1950 個取得...
#
# ページ 66 を取得中... (URL: https://github.com/orgs/google/repositories?page=66...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 1980 個取得...
#
# ページ 67 を取得中... (URL: https://github.com/orgs/google/repositories?page=67...)
# 合計 1980 個取得...
#
# ページ 67 を取得中... (URL: https://github.com/orgs/google/repositories?page=67...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2010 個取得...
#
# ページ 68 を取得中... (URL: https://github.com/orgs/google/repositories?page=68...)
# 合計 2010 個取得...
#
# ページ 68 を取得中... (URL: https://github.com/orgs/google/repositories?page=68...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2040 個取得...
#
# ページ 69 を取得中... (URL: https://github.com/orgs/google/repositories?page=69...)
# 合計 2040 個取得...
#
# ページ 69 を取得中... (URL: https://github.com/orgs/google/repositories?page=69...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2070 個取得...
#
# ページ 70 を取得中... (URL: https://github.com/orgs/google/repositories?page=70...)
# 合計 2070 個取得...
#
# ページ 70 を取得中... (URL: https://github.com/orgs/google/repositories?page=70...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2100 個取得...
#
# ページ 71 を取得中... (URL: https://github.com/orgs/google/repositories?page=71...)
# 合計 2100 個取得...
#
# ページ 71 を取得中... (URL: https://github.com/orgs/google/repositories?page=71...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2130 個取得...
#
# ページ 72 を取得中... (URL: https://github.com/orgs/google/repositories?page=72...)
# 合計 2130 個取得...
#
# ページ 72 を取得中... (URL: https://github.com/orgs/google/repositories?page=72...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2160 個取得...
#
# ページ 73 を取得中... (URL: https://github.com/orgs/google/repositories?page=73...)
# 合計 2160 個取得...
#
# ページ 73 を取得中... (URL: https://github.com/orgs/google/repositories?page=73...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2190 個取得...
#
# ページ 74 を取得中... (URL: https://github.com/orgs/google/repositories?page=74...)
# 合計 2190 個取得...
#
# ページ 74 を取得中... (URL: https://github.com/orgs/google/repositories?page=74...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2220 個取得...
#
# ページ 75 を取得中... (URL: https://github.com/orgs/google/repositories?page=75...)
# 合計 2220 個取得...
#
# ページ 75 を取得中... (URL: https://github.com/orgs/google/repositories?page=75...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2250 個取得...
#
# ページ 76 を取得中... (URL: https://github.com/orgs/google/repositories?page=76...)
# 合計 2250 個取得...
#
# ページ 76 を取得中... (URL: https://github.com/orgs/google/repositories?page=76...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2280 個取得...
#
# ページ 77 を取得中... (URL: https://github.com/orgs/google/repositories?page=77...)
# 合計 2280 個取得...
#
# ページ 77 を取得中... (URL: https://github.com/orgs/google/repositories?page=77...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2310 個取得...
#
# ページ 78 を取得中... (URL: https://github.com/orgs/google/repositories?page=78...)
# 合計 2310 個取得...
#
# ページ 78 を取得中... (URL: https://github.com/orgs/google/repositories?page=78...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2340 個取得...
#
# ページ 79 を取得中... (URL: https://github.com/orgs/google/repositories?page=79...)
# 合計 2340 個取得...
#
# ページ 79 を取得中... (URL: https://github.com/orgs/google/repositories?page=79...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2370 個取得...
#
# ページ 80 を取得中... (URL: https://github.com/orgs/google/repositories?page=80...)
# 合計 2370 個取得...
#
# ページ 80 を取得中... (URL: https://github.com/orgs/google/repositories?page=80...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2400 個取得...
#
# ページ 81 を取得中... (URL: https://github.com/orgs/google/repositories?page=81...)
# 合計 2400 個取得...
#
# ページ 81 を取得中... (URL: https://github.com/orgs/google/repositories?page=81...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2430 個取得...
#
# ページ 82 を取得中... (URL: https://github.com/orgs/google/repositories?page=82...)
# 合計 2430 個取得...
#
# ページ 82 を取得中... (URL: https://github.com/orgs/google/repositories?page=82...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2460 個取得...
#
# ページ 83 を取得中... (URL: https://github.com/orgs/google/repositories?page=83...)
# 合計 2460 個取得...
#
# ページ 83 を取得中... (URL: https://github.com/orgs/google/repositories?page=83...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2490 個取得...
#
# ページ 84 を取得中... (URL: https://github.com/orgs/google/repositories?page=84...)
# 合計 2490 個取得...
#
# ページ 84 を取得中... (URL: https://github.com/orgs/google/repositories?page=84...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2520 個取得...
#
# ページ 85 を取得中... (URL: https://github.com/orgs/google/repositories?page=85...)
# 合計 2520 個取得...
#
# ページ 85 を取得中... (URL: https://github.com/orgs/google/repositories?page=85...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2550 個取得...
#
# ページ 86 を取得中... (URL: https://github.com/orgs/google/repositories?page=86...)
# 合計 2550 個取得...
#
# ページ 86 を取得中... (URL: https://github.com/orgs/google/repositories?page=86...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2580 個取得...
#
# ページ 87 を取得中... (URL: https://github.com/orgs/google/repositories?page=87...)
# 合計 2580 個取得...
#
# ページ 87 を取得中... (URL: https://github.com/orgs/google/repositories?page=87...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2610 個取得...
#
# ページ 88 を取得中... (URL: https://github.com/orgs/google/repositories?page=88...)
# 合計 2610 個取得...
#
# ページ 88 を取得中... (URL: https://github.com/orgs/google/repositories?page=88...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2640 個取得...
#
# ページ 89 を取得中... (URL: https://github.com/orgs/google/repositories?page=89...)
# 合計 2640 個取得...
#
# ページ 89 を取得中... (URL: https://github.com/orgs/google/repositories?page=89...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2670 個取得...
#
# ページ 90 を取得中... (URL: https://github.com/orgs/google/repositories?page=90...)
# 合計 2670 個取得...
#
# ページ 90 を取得中... (URL: https://github.com/orgs/google/repositories?page=90...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2700 個取得...
#
# ページ 91 を取得中... (URL: https://github.com/orgs/google/repositories?page=91...)
# 合計 2700 個取得...
#
# ページ 91 を取得中... (URL: https://github.com/orgs/google/repositories?page=91...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2730 個取得...
#
# ページ 92 を取得中... (URL: https://github.com/orgs/google/repositories?page=92...)
# 合計 2730 個取得...
#
# ページ 92 を取得中... (URL: https://github.com/orgs/google/repositories?page=92...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2760 個取得...
#
# ページ 93 を取得中... (URL: https://github.com/orgs/google/repositories?page=93...)
# 合計 2760 個取得...
#
# ページ 93 を取得中... (URL: https://github.com/orgs/google/repositories?page=93...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# ステータスコード: 200
# このページで取得したリポジトリ数: 30
# 合計 2790 個取得...
#
# ページ 94 を取得中... (URL: https://github.com/orgs/google/repositories?page=94...)
# 合計 2790 個取得...
#
# ページ 94 を取得中... (URL: https://github.com/orgs/google/repositories?page=94...)
# ステータスコード: 200
# このページで取得したリポジトリ数: 22
# ステータスコード: 200
# このページで取得したリポジトリ数: 22
#
# ページ 94: リポジトリ数が30未満。スクレイピング終了
#
# === スクレイピング完了 ===
# 合計 2812 個のリポジトリをデータベースに保存しました
#
# ページ 94: リポジトリ数が30未満。スクレイピング終了
#
# === スクレイピング完了 ===
# 合計 2812 個のリポジトリをデータベースに保存しました
